# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import os
import numpy as np
from sklearn.cluster import KMeans

# %% [markdown]
# ### Define Function

# %%
def check_status(value):
    if value in range(100, 199):
        return 1
    elif value in range(200, 299):
        return 2
    elif value in range(300, 399):
        return 3
    elif value in range(400, 499):
        return 4
    elif value in range(500, 600):
        return 5

def check_size(value):
    if value in range(0, 1000):
        return 1
    elif value in range(1001, 5000):
        return 2
    elif value in range(5001, 10000):
        return 3
    elif value in range(10001, 15000):
        return 4
    elif value > 15000:
        return 5

# %% [markdown]
# ### Load Datasets

# %%
data = pd.read_csv('DATA.csv',sep= ';')
data
# Out:
#           Ip Address  User Identifier  User Identity       Date      Time  \
# 0       192.168.1.16                0              0  04-Dec-18  21:52:00
# 1       192.168.1.16                0              0  05-Dec-18  18:48:30
# 2     64.233.173.168                0              0  06-Dec-18   8:30:03
# 3       192.168.1.16                0              0  06-Dec-18   9:28:40
# 4     64.233.173.170                0              0  06-Dec-18  20:42:00
# 5       192.168.1.16                0              0  07-Dec-18  14:21:02
# 6       192.168.1.16                0              0  07-Dec-18  14:31:00
# 7     64.233.173.172                0              0  07-Dec-18  19:37:00
# 8       192.168.1.16                0              0  07-Dec-18  20:13:00
# 9       192.168.1.16                0              0  07-Dec-18  21:38:04
# 10    192.168.43.172                0              0  04-Dec-18  23:50:16
# 11    192.168.43.172                0              0  05-Dec-18   0:19:38
# 12    192.168.43.172                0              0  05-Dec-18   7:54:27
# 13    64.233.173.172                0              0  05-Dec-18   9:28:03
# 14    192.168.43.172                0              0  05-Dec-18  16:31:40
# 15    192.168.43.172                0              0  06-Dec-18   0:32:53
# 16    192.168.43.172                0              0  06-Dec-18  15:38:36
# 17    192.168.43.172                0              0  06-Dec-18  21:42:27
# 18    192.168.43.172                0              0  06-Dec-18  22:17:37
# 19    192.168.43.172                0              0  07-Dec-18  23:20:23
# 20    192.168.43.157                0              0  02-Dec-18   9:07:24
# 21    192.168.43.157                0              0  02-Dec-18   9:16:38
# 22    192.168.43.157                0              0  02-Dec-18  17:16:45
# 23    192.168.43.157                0              0  03-Dec-18  20:31:39
# 24    192.168.43.157                0              0  04-Dec-18  18:27:40
# 25    192.168.43.157                0              0  05-Dec-18   7:50:22
# 26    192.168.43.157                0              0  05-Dec-18  17:38:03
# 27    192.168.43.157                0              0  06-Dec-18   6:21:50
# 28    192.168.43.157                0              0  06-Dec-18  21:51:19
# 29    192.168.43.157                0              0  07-Dec-18  19:20:33
# ..               ...              ...            ...        ...       ...
# 119      192.168.1.9                0              0  03-Dec-18  23:47:26
# 120      10.0.36.123                0              0  04-Dec-18  12:08:15
# 121      192.168.1.9                0              0  05-Dec-18  18:39:21
# 122   192.168.43.172                0              0  06-Dec-18  15:23:11
# 123     192.168.1.12                0              0  07-Dec-18  16:41:33
# 124   192.168.43.241                0              0  04-Dec-18  12:00:50
# 125    114.5.144.180                0              0  04-Dec-18  12:01:58
# 126    114.5.144.180                0              0  04-Dec-18  12:03:05
# 127    114.5.144.180                0              0  04-Dec-18  12:03:54
# 128    114.5.144.180                0              0  04-Dec-18  12:05:15
# 129     36.73.97.156                0              0  05-Dec-18   5:44:28
# 130     36.73.97.156                0              0  05-Dec-18  53:45:43
# 131     36.73.97.156                0              0  05-Dec-18   5:46:26
# 132     36.73.97.156                0              0  05-Dec-18   5:48:52
# 133     36.73.97.156                0              0  05-Dec-18   5:49:39
# 134    114.5.144.180                0              0  04-Dec-18  12:06:44
# 135    114.5.144.180                0              0  04-Dec-18  12:09:02
# 136    114.5.144.180                0              0  04-Dec-18  12:09:56
# 137    114.5.144.180                0              0  04-Dec-18  12:10:48
# 138    114.5.144.180                0              0  04-Dec-18  12:11:56
# 139  146.185.157.238                0              0  07-Dec-18   5:21:46
# 140     36.73.97.156                0              0  07-Dec-18   5:22:50
# 141     36.73.97.156                0              0  07-Dec-18   5:23:46
# 142     36.73.97.156                0              0  07-Dec-18   5:24:34
# 143  146.185.157.238                0              0  07-Dec-18   5:26:07
# 144  146.185.157.238                0              0  07-Dec-18   5:27:17
# 145     36.73.97.156                0              0  07-Dec-18   5:28:14
# 146    192.168.1.112                0              0  07-Dec-18   5:29:43
# 147    162.243.127.7                0              0  03-Dec-18  13:20:43
# 148    162.243.127.7                0              0  03-Dec-18  13:22:07
#
#                                           Page Request  Status  Size Request  \
# 0           https://portal.uad.ac.id/pembayaran/Kuliah     200           621
# 1         https://portal.uad.ac.id/transkrip/Transkrip     200         54947
# 2           https://portal.uad.ac.id/prestasi/prestasi     302         35754
# 3         https://portal.uad.ac.id/transkrip/Transkrip     200           542
# 4           https://portal.uad.ac.id/presensi/presensi     304           453
# 5                  https://portal.uad.ac.id/cdc/Agenda     200           453
# 6               https://portal.uad.ac.id/wisuda/Wisuda     200           345
# 7            https://portal.uad.ac.id/perpus/sirkulasi     200           455
# 8             https://portal.uad.ac.id/skripsi/Skripsi     304           355
# 9           https://portal.uad.ac.id/lsp/Asesmen/index     200           454
# 10        https://portal.uad.ac.id/transkrip/Transkrip     302           504
# 11          https://portal.uad.ac.id/pembayaran/Kuliah     302           621
# 12                    https://portal.uad.ac.id/khs/Khs     302         54947
# 13                           https://portal.uad.ac.id/     200         35754
# 14                  https://portal.uad.ac.id/skpi/Skpi     240           542
# 15                    https://portal.uad.ac.id/khs/Khs     200           453
# 16        https://portal.uad.ac.id/transkrip/Transkrip     201           453
# 17        https://portal.uad.ac.id/transkrip/Transkrip     204           345
# 18                  https://portal.uad.ac.id/skpi/Skpi     104           455
# 19                           https://portal.uad.ac.id/     200           355
# 20                    https://portal.uad.ac.id/tbq/Tbq     200           454
# 21    https://portal.uad.ac.id/presensi/Presensi/index     200           504
# 22          https://portal.uad.ac.id/pembayaran/Kuliah     200           621
# 23              https://portal.uad.ac.id/khs/Khs/index     302         54947
# 24        https://portal.uad.ac.id/transkrip/Transkrip     302         35754
# 25    https://portal.uad.ac.id/presensi/Presensi/index     208           542
# 26              https://portal.uad.ac.id/khs/Khs/index     200           453
# 27    https://portal.uad.ac.id/presensi/Presensi/index     200           453
# 28          https://portal.uad.ac.id/pembayaran/Kuliah     220           345
# 29    https://portal.uad.ac.id/presensi/Presensi/index     200           455
# ..                                                 ...     ...           ...
# 119         https://portal.uad.ac.id/pembayaran/Kuliah     200           542
# 120                 https://portal.uad.ac.id/skpi/Skpi     200           453
# 121             https://portal.uad.ac.id/wisuda/Wisuda     208           542
# 122         https://portal.uad.ac.id/lsp/Asesmen/index     200           453
# 123         https://portal.uad.ac.id/lsp/Asesmen/index     200           453
# 124                          https://portal.uad.ac.id/     220           345
# 125       https://portal.uad.ac.id/transkrip/Transkrip     200           455
# 126               https://portal.uad.ac.id/kelas/Kelas     302           355
# 127         https://portal.uad.ac.id/kelas/Kelas/index     300           454
# 128  https://portal.uad.ac.id/forum/Forum/hashtag/s...     320           504
# 129                 https://portal.uad.ac.id/dashboard     402           621
# 130   https://portal.uad.ac.id/presensi/Presensi/index     402         54947
# 131                   https://portal.uad.ac.id/krs/Krs     402         35754
# 132             https://portal.uad.ac.id/wisuda/Wisuda     400           542
# 133             https://portal.uad.ac.id/khs/Khs/index     200           453
# 134  https://portal.uad.ac.id/forum/Forum/hashtag/s...     200           453
# 135           https://portal.uad.ac.id/skripsi/Skripsi     201           345
# 136             https://portal.uad.ac.id/tahsin/Tahsin     200           455
# 137          https://portal.uad.ac.id/perpus/Sirkulasi     302           355
# 138            https://portal.uad.ac.id/wifi/Mahasiswa     200           454
# 139                   https://portal.uad.ac.id/profile     300           504
# 140                          https://portal.uad.ac.id/     300           621
# 141           https://portal.uad.ac.id/skripsi/Skripsi     204           400
# 142   https://portal.uad.ac.id/presensi/Presensi/index     203           368
# 143         https://portal.uad.ac.id/pembayaran/Kuliah     200           542
# 144       https://portal.uad.ac.id/praktikum/Praktikum     200           453
# 145         https://portal.uad.ac.id/beasiswa/Beasiswa     208           542
# 146                 https://portal.uad.ac.id/skpi/Skpi     200           453
# 147            https://portal.uad.ac.id/wifi/Mahasiswa     200           453
# 148                     https://portal.uad.ac.id/inbox     220           345
#
#      Reference            Browser
# 0            0      Google chrome
# 1            0      Google chrome
# 2            0      Google Chrome
# 3            0      Google Chrome
# 4            0      Google Chrome
# 5            0      Google Chrome
# 6            0      Google Chrome
# 7            0      Google Chrome
# 8            0      Google Chrome
# 9            0      Google Chrome
# 10           0            Mozilla
# 11           0            Mozilla
# 12           0  Internet Explorer
# 13           0             Chrome
# 14           0            Mozilla
# 15           0            Mozilla
# 16           0            Mozilla
# 17           0            Mozilla
# 18           0            Mozilla
# 19           0            Mozilla
# 20           0             Chrome
# 21           0             Chrome
# 22           0             Chrome
# 23           0             Chrome
# 24           0             Chrome
# 25           0             Chrome
# 26           0             Chrome
# 27           0             Chrome
# 28           0             Chrome
# 29           0             Chrome
# ..         ...                ...
# 119          0             Chrome
# 120          0             Chrome
# 121          0             Chrome
# 122          0             Chrome
# 123          0             Chrome
# 124          0            Mozilla
# 125          0            Mozilla
# 126          0            Mozilla
# 127          0            Mozilla
# 128          0            Mozilla
# 129          0             Chrome
# 130          0             Chrome
# 131          0             Chrome
# 132          0            Mozilla
# 133          0            Mozilla
# 134          0            Mozilla
# 135          0            Mozilla
# 136          0            Mozilla
# 137          0            Mozilla
# 138          0            Mozilla
# 139          0             Chrome
# 140          0            Mozilla
# 141          0            Mozilla
# 142          0            Mozilla
# 143          0             Chrome
# 144          0             Chrome
# 145          0            Mozilla
# 146          0             Chrome
# 147          0             Chrome
# 148          0             Chrome
#
# [149 rows x 10 columns]

# %% [markdown]
# ### Define List Month

# %%
list_bulan = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %% [markdown]
# ### Preprocessing Datasets

# %%
preprocessing = []
for i in range(len(data['Time'])):
    tmp_date = data['Date'][i].split("-")
    tmp_date[1] = list_bulan.index(tmp_date[1]) + 1
    tmp_time = list(map(int, data['Time'][i].split(":")))
    tmp_date = list(map(int, tmp_date))
    stat = [check_status(data['Status'][i])]
    stat_size = [check_size(data['Size Request'][i])]
    gabung = tmp_date + tmp_time + stat + stat_size
    preprocessing.append(gabung)
preprocessing = pd.DataFrame(preprocessing,columns=['Tanggal','Bulan','Tahun','Pukul','Menit','Detik','Status','Size Request'])
preprocessing
# Out:
#      Tanggal  Bulan  Tahun  Pukul  Menit  Detik  Status  Size Request
# 0          4     12     18     21     52      0       2             1
# 1          5     12     18     18     48     30       2             5
# 2          6     12     18      8     30      3       3             5
# 3          6     12     18      9     28     40       2             1
# 4          6     12     18     20     42      0       3             1
# 5          7     12     18     14     21      2       2             1
# 6          7     12     18     14     31      0       2             1
# 7          7     12     18     19     37      0       2             1
# 8          7     12     18     20     13      0       3             1
# 9          7     12     18     21     38      4       2             1
# 10         4     12     18     23     50     16       3             1
# 11         5     12     18      0     19     38       3             1
# 12         5     12     18      7     54     27       3             5
# 13         5     12     18      9     28      3       2             5
# 14         5     12     18     16     31     40       2             1
# 15         6     12     18      0     32     53       2             1
# 16         6     12     18     15     38     36       2             1
# 17         6     12     18     21     42     27       2             1
# 18         6     12     18     22     17     37       1             1
# 19         7     12     18     23     20     23       2             1
# 20         2     12     18      9      7     24       2             1
# 21         2     12     18      9     16     38       2             1
# 22         2     12     18     17     16     45       2             1
# 23         3     12     18     20     31     39       3             5
# 24         4     12     18     18     27     40       3             5
# 25         5     12     18      7     50     22       2             1
# 26         5     12     18     17     38      3       2             1
# 27         6     12     18      6     21     50       2             1
# 28         6     12     18     21     51     19       2             1
# 29         7     12     18     19     20     33       2             1
# ..       ...    ...    ...    ...    ...    ...     ...           ...
# 119        3     12     18     23     47     26       2             1
# 120        4     12     18     12      8     15       2             1
# 121        5     12     18     18     39     21       2             1
# 122        6     12     18     15     23     11       2             1
# 123        7     12     18     16     41     33       2             1
# 124        4     12     18     12      0     50       2             1
# 125        4     12     18     12      1     58       2             1
# 126        4     12     18     12      3      5       3             1
# 127        4     12     18     12      3     54       3             1
# 128        4     12     18     12      5     15       3             1
# 129        5     12     18      5     44     28       4             1
# 130        5     12     18     53     45     43       4             5
# 131        5     12     18      5     46     26       4             5
# 132        5     12     18      5     48     52       4             1
# 133        5     12     18      5     49     39       2             1
# 134        4     12     18     12      6     44       2             1
# 135        4     12     18     12      9      2       2             1
# 136        4     12     18     12      9     56       2             1
# 137        4     12     18     12     10     48       3             1
# 138        4     12     18     12     11     56       2             1
# 139        7     12     18      5     21     46       3             1
# 140        7     12     18      5     22     50       3             1
# 141        7     12     18      5     23     46       2             1
# 142        7     12     18      5     24     34       2             1
# 143        7     12     18      5     26      7       2             1
# 144        7     12     18      5     27     17       2             1
# 145        7     12     18      5     28     14       2             1
# 146        7     12     18      5     29     43       2             1
# 147        3     12     18     13     20     43       2             1
# 148        3     12     18     13     22      7       2             1
#
# [149 rows x 8 columns]

# %% [markdown]
# ### Get Frequently Access Grouping By Date

# %%
get_column_date = pd.DataFrame(preprocessing['Tanggal'])
get_column_date.columns = ['Tanggal']
grouping_by_date = get_column_date.drop_duplicates().sort_values(by=['Tanggal'])
get_frequently = get_column_date.groupby('Tanggal').size()
grouping_by_date['Frequently'] = get_frequently.values
grouping_by_date
# Out:
#     Tanggal  Frequently
# 30        1          13
# 20        2          19
# 23        3          22
# 0         4          18
# 1         5          23
# 2         6          19
# 5         7          35

# %% [markdown]
# ### Timestamp Transformations

# %%
date_list = [x for x in grouping_by_date['Tanggal']]
date_0 = [x for x in grouping_by_date['Frequently']]
date_1 = [x for x in grouping_by_date['Frequently'][1:]]
date_2 = [x for x in grouping_by_date['Frequently'][2:]]
date_transformation = [date_list, date_0, date_1, date_2]
date_transformation_df = pd.DataFrame(date_transformation).transpose().fillna(0).astype(int)
date_transformation_df.columns = ['Tanggal', 'Data T_0', 'Data T_1', 'Data T_2']
date_transformation_df
# Out:
#    Tanggal  Data T_0  Data T_1  Data T_2
# 0        1        13        19        22
# 1        2        19        22        18
# 2        3        22        18        23
# 3        4        18        23        19
# 4        5        23        19        35
# 5        6        19        35         0
# 6        7        35         0         0

# %% [markdown]
# ### Cluster with K Means

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(date_transformation_df)
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
labels = kmeans.predict(date_transformation_df)
labels
# Out:
# array([0, 0, 0, 0, 0, 1, 2])

# %%
centroids = kmeans.cluster_centers_
list_label = list(range(len(centroids)))
centroids
# Out:
# array([[ 3. , 19. , 20.2, 23.4],
#        [ 6. , 19. , 35. ,  0. ],
#        [ 7. , 35. ,  0. ,  0. ]])

# %%
new_date_transformation_df = date_transformation_df.copy()
new_date_transformation_df['Cluster'] = labels
new_date_transformation_df
# Out:
#    Tanggal  Data T_0  Data T_1  Data T_2  Cluster
# 0        1        13        19        22        0
# 1        2        19        22        18        0
# 2        3        22        18        23        0
# 3        4        18        23        19        0
# 4        5        23        19        35        0
# 5        6        19        35         0        1
# 6        7        35         0         0        2
