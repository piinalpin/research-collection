# %% [markdown]
# # Import Library

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
import numpy.linalg as LA
import pandas as pd
import string 
from openpyxl import load_workbook

# %% [markdown]
# # Custom Libraries

# %%
class Engine:
    def __init__(self):
        self.cosine_score = []
        self.train_set = []  # Documents
        self.test_set = []  # Query

    def addDocument(self, word):
        self.train_set.append(word)

    def setQuery(self, word):
        self.test_set.append(word)

    def process_score(self):
        stopWords = stopwords.words('english')
        vectorizer = CountVectorizer()

        transformer = TfidfTransformer()

        trainVectorizerArray = vectorizer.fit_transform(self.train_set).toarray()
        testVectorizerArray = vectorizer.transform(self.test_set).toarray()

        cx = lambda a, b: round(np.inner(a, b) / (LA.norm(a) * LA.norm(b)), 3)
        # print testVectorizerArray
        output = []
        for i in range(0, len(testVectorizerArray)):
            output.append([])

        for vector in trainVectorizerArray:
            # print vector
            u = 0
            for testV in testVectorizerArray:
                # print testV
                cosine = cx(vector, testV)
                # self.cosine_score.append(cosine)
                # bulatin = (round(cosine),2)
                output[u].append((cosine))
                u = u + 1
        return output
        # return testVectorizerArray
    
    def check_tag(self,tag,tags):
        # data_tag = tag.split(',')
        # data_tags = tags.split(',')
        stat = False
        if tag in tags:
            stat = True
        return stat

# %% [markdown]
# # Load Dataset Khotbah

# %%
data = pd.read_excel('preprocessed-dataset.xlsx', sep=',', encoding='latin')
dt = data['preprocessed']
dt
# Out:
# 0      keliru masalah syarat sah shalat ibadallah sun...
# 1      allah maha tahu apa kerja khotib wasiat diri k...
# 2      duduk ulama tengah masyarakat antara nikmat al...
# 3      pimpin sesat ibadallah hidup zaman penuh fitna...
# 4      dzikir ingat allah kuat jiwa raga sungguh oran...
# 5      banding nikmat dunia nikmat akhirat hadirin ra...
# 6      rahasia baca surat al fatihah ibadallah takwa ...
# 7      butuh taubat ibadallah khotib wasiat diri khot...
# 8      utama taubat istighfar ibadallah mari takwa al...
# 9      metadabburi alquran surat yunus khotib wasiat ...
# 10     jaga waktu kaum muslimin khotib wasiat diri kh...
# 11     hal tunjuk kuat imam ibadallah khotib wasiat d...
# 12     khotbah masjid haram utama syukur jadi orang s...
# 13     khawarij kontemporer ibadallah abad ini sunggu...
# 14     sejarah awal mula ronta islam ibadallah catat ...
# 15     cara allah laku orang taat dosa takwa allah be...
# 16     mimpi pandang islam ayyuhal mukminun takwa all...
# 17     utama ilmu agama kiat dapat ibadallah sungguh ...
# 18     lawan masa tua ibadallah manusiaakan alami tum...
# 19     doa kepada niscaya aku kabul ibadallah doa moh...
# 20     ajar syahid utsman bin affan ibadallah takwa a...
# 21     musuh yahudi islam ibadallah musuh yahudi isla...
# 22     rumah setan ibadallah semua orang milik rumah ...
# 23     kisah musa ikut sama firaun ikut ayyuhannas ta...
# 24     kiat wujud aman stabilitas negara ibadallah pi...
# 25     liberalisme hakikat ajak orang tak agama ibada...
# 26     hidayah karunia ilahi ayyuhal mukminun ibadall...
# 27     dayuts masuk surga ibadallah allah azza wa jal...
# 28     mudah ibadah haji ibadallah haji rupa rukun is...
# 29     jalan raih ridha arrahman ibadallah bagi besar...
#                              ...
# 330    makna rahmat allah swt hadirin jamaah jum baha...
# 331    jangan muka masam jamaah jum rahimakumullah wa...
# 332    gerhana bukti agung allah mari sama panjat puj...
# 333    pelihara sifat qana ah jamaah shalat jum bahag...
# 334    optimis hidup kaum muslimin sidang jum rahimak...
# 335    raih hikmah allah asyiral muslimin rahimakumul...
# 336    dahsyat rayu sesat jamaah sidang jum mulia all...
# 337    kurikulum anak shalih kaum muslimin rahmat all...
# 338    syarat raih bahagia hadirin sidang jum bahagia...
# 339    jaga takwa majelis jum rahimakumullah pertamat...
# 340    usir malas hadirin jamaah shalat jum mulia all...
# 341    tragedi pahlawan ilmuwan dermawan berandaianda...
# 342    khutbah idul fitri fitrah mulia islam hadap wa...
# 343    khutbah id yunahar ilyas aman damai hadir bapa...
# 344    khutbah id haedar nashir puasa bentuk perilaku...
# 345    anak investasi dunia akhirat jamaah sidang jum...
# 346    gera amal alqur asyiral muslimin rahimakumulla...
# 347    fenomena bunuh diri jamaah sidang jum mulia al...
# 348    jadi umat baik kaum muslimin jamaah shalat jum...
# 349    fitrah manusia milik sifat optimis jamaah sida...
# 350    khutbah idul adha tanam nilai kurban hidup mas...
# 351    khutbah idul adha 1437 h makna esensi ibadah h...
# 352    nasihat rasulullah saw umat asyiral muslimin r...
# 353    dasar bangun keluarga sakinah jamaah jum rahim...
# 354    muharram bukan bulan sial asyiral muslimin rah...
# 355    tragedi pahlawan ilmuwan dermawan jamaah sidan...
# 356    komitmen ilmu islam jamaah sidang jum ah dimul...
# 357    negeri baldatun thoyibatun warabun ghofur jama...
# 358    bangkit etos kerja muslim jamaah sidang jum ah...
# 359    muslim makmur bumi jama ah shalat jum rahmat a...
# Name: preprocessed, Length: 360, dtype: object

# %% [markdown]
# # Load Dataset Khotbah Query

# %%
queri = pd.read_excel('trend.xlsx', sep=',', encoding='latin')
queries = queri['trend'][10:11]
queries
# Out:
# 10    indonesia memilih
# Name: trend, dtype: object

# %% [markdown]
# # TF IDF dan Cosine Similarity

# %%
engine = Engine()

list_dokumenkhotbah = [str(x) for x in data['preprocessed']]

columnNames = []

for i, doc in enumerate(list_dokumenkhotbah):
    engine.addDocument(doc)
    columnNames.append("Document_{}".format(i+1))
    
for query in queries:
    engine.setQuery(query)
    
doc_score = engine.process_score()
docScoreDf = pd.DataFrame(doc_score).T
docScoreDf.columns = queries
docScoreDf["Documents"] = columnNames
docScoreDf["Link"] = data["Link"].values
docScoreDf
# Out:
# trend  indonesia memilih     Documents  \
# 0                  0.000    Document_1
# 1                  0.000    Document_2
# 2                  0.000    Document_3
# 3                  0.000    Document_4
# 4                  0.000    Document_5
# 5                  0.000    Document_6
# 6                  0.000    Document_7
# 7                  0.000    Document_8
# 8                  0.000    Document_9
# 9                  0.000   Document_10
# 10                 0.000   Document_11
# 11                 0.000   Document_12
# 12                 0.000   Document_13
# 13                 0.000   Document_14
# 14                 0.000   Document_15
# 15                 0.000   Document_16
# 16                 0.000   Document_17
# 17                 0.000   Document_18
# 18                 0.000   Document_19
# 19                 0.000   Document_20
# 20                 0.000   Document_21
# 21                 0.000   Document_22
# 22                 0.000   Document_23
# 23                 0.000   Document_24
# 24                 0.000   Document_25
# 25                 0.000   Document_26
# 26                 0.000   Document_27
# 27                 0.000   Document_28
# 28                 0.000   Document_29
# 29                 0.000   Document_30
# ..                   ...           ...
# 330                0.000  Document_331
# 331                0.000  Document_332
# 332                0.012  Document_333
# 333                0.000  Document_334
# 334                0.000  Document_335
# 335                0.026  Document_336
# 336                0.059  Document_337
# 337                0.000  Document_338
# 338                0.000  Document_339
# 339                0.000  Document_340
# 340                0.000  Document_341
# 341                0.000  Document_342
# 342                0.000  Document_343
# 343                0.041  Document_344
# 344                0.012  Document_345
# 345                0.021  Document_346
# 346                0.066  Document_347
# 347                0.018  Document_348
# 348                0.030  Document_349
# 349                0.000  Document_350
# 350                0.000  Document_351
# 351                0.000  Document_352
# 352                0.000  Document_353
# 353                0.000  Document_354
# 354                0.000  Document_355
# 355                0.000  Document_356
# 356                0.000  Document_357
# 357                0.021  Document_358
# 358                0.000  Document_359
# 359                0.000  Document_360
#
# trend                                               Link
# 0      https://khotbahjumat.com/5254-kekeliruan-dalam...
# 1      https://khotbahjumat.com/5251-allah-maha-menge...
# 2      https://khotbahjumat.com/5232-kedudukan-ulama-...
# 3      https://khotbahjumat.com/5223-pemimpin-yang-me...
# 4      https://khotbahjumat.com/5213-berdzikir-mengin...
# 5      https://khotbahjumat.com/5190-perbandingan-nik...
# 6      https://khotbahjumat.com/5179-rahasia-dalam-ba...
# 7      https://khotbahjumat.com/5176-kita-butuh-berta...
# 8      https://khotbahjumat.com/5173-keutamaan-taubat...
# 9      https://khotbahjumat.com/5156-menadabburi-alqu...
# 10      https://khotbahjumat.com/5146-menjaga-waktu.html
# 11     https://khotbahjumat.com/5136-hal-hal-yang-men...
# 12     https://khotbahjumat.com/5121-khotbah-masjid-h...
# 13     https://khotbahjumat.com/5076-khawarij-kontemp...
# 14     https://khotbahjumat.com/5064-sejarah-awal-mul...
# 15     https://khotbahjumat.com/5005-cara-allah-mempe...
# 16     https://khotbahjumat.com/4998-mimpi-dalam-pand...
# 17     https://khotbahjumat.com/4967-keutamaan-ilmu-a...
# 18     https://khotbahjumat.com/4949-melawan-masa-tua...
# 19     https://khotbahjumat.com/4919-berdoalah-kepada...
# 20     https://khotbahjumat.com/4907-pelajaran-dari-s...
# 21     https://khotbahjumat.com/4892-permusuhan-yahud...
# 22     https://khotbahjumat.com/4866-agar-tidak-serum...
# 23     https://khotbahjumat.com/4804-kisah-musa-dan-p...
# 24     https://khotbahjumat.com/4786-kiat-agar-terwuj...
# 25     https://khotbahjumat.com/4778-liberalisme-haki...
# 26     https://khotbahjumat.com/4774-hidayah-adalah-k...
# 27     https://khotbahjumat.com/4758-dayuts-tidak-mas...
# 28     https://khotbahjumat.com/4752-kemudahan-dalam-...
# 29     https://khotbahjumat.com/4733-perjalanan-merai...
# ..                                                   ...
# 330    http://www.suaramuhammadiyah.id/2016/02/18/mem...
# 331    http://www.suaramuhammadiyah.id/2016/02/25/jan...
# 332    http://www.suaramuhammadiyah.id/2016/02/26/ger...
# 333    http://www.suaramuhammadiyah.id/2016/03/03/mem...
# 334    http://www.suaramuhammadiyah.id/2016/03/10/opt...
# 335    http://www.suaramuhammadiyah.id/2016/03/17/mer...
# 336    http://www.suaramuhammadiyah.id/2016/03/31/dah...
# 337    http://www.suaramuhammadiyah.id/2016/04/07/kur...
# 338    http://www.suaramuhammadiyah.id/2016/04/21/sya...
# 339    http://www.suaramuhammadiyah.id/2016/04/28/men...
# 340    http://www.suaramuhammadiyah.id/2016/05/12/men...
# 341    http://www.suaramuhammadiyah.id/2016/05/26/men...
# 342    http://www.suaramuhammadiyah.id/2016/06/23/tra...
# 343    http://www.suaramuhammadiyah.id/2016/06/29/khu...
# 344    http://www.suaramuhammadiyah.id/2016/07/01/aga...
# 345    http://www.suaramuhammadiyah.id/2016/07/01/pua...
# 346    http://www.suaramuhammadiyah.id/2016/07/28/ana...
# 347    http://www.suaramuhammadiyah.id/2016/08/04/ger...
# 348    http://www.suaramuhammadiyah.id/2016/08/11/dua...
# 349    http://www.suaramuhammadiyah.id/2016/08/18/men...
# 350    http://www.suaramuhammadiyah.id/2016/08/25/fit...
# 351    http://www.suaramuhammadiyah.id/2016/09/10/khu...
# 352    http://www.suaramuhammadiyah.id/2016/09/10/khu...
# 353    http://www.suaramuhammadiyah.id/2016/09/15/nas...
# 354    http://www.suaramuhammadiyah.id/2016/09/22/das...
# 355    http://www.suaramuhammadiyah.id/2016/09/29/muh...
# 356    http://www.suaramuhammadiyah.id/2016/10/27/kom...
# 357    http://www.suaramuhammadiyah.id/2017/01/26/neg...
# 358    http://www.suaramuhammadiyah.id/2017/02/16/mem...
# 359    http://www.suaramuhammadiyah.id/2017/02/16/mus...
#
# [360 rows x 3 columns]

# %% [markdown]
# # Label Relevan

# %%
df_listed = []
for i in queries:
    labels = list()
    for j in docScoreDf[i]:
        if j>0.000:
            labels.append(1)
        else:
            labels.append(0)
    datadf = pd.DataFrame(docScoreDf[i])
    datadf['Documents'] = docScoreDf['Documents']
    datadf['Label'] = labels
    datadf['Link'] = docScoreDf["Link"].values
    df_listed.append(datadf.sort_values(by=[i], ascending=False))
df_listed
# Out:
# [     indonesia memilih     Documents  Label  \
#  287              0.130  Document_288      1
#  325              0.084  Document_326      1
#  346              0.066  Document_347      1
#  122              0.060  Document_123      1
#  336              0.059  Document_337      1
#  310              0.051  Document_311      1
#  246              0.045  Document_247      1
#  343              0.041  Document_344      1
#  193              0.035  Document_194      1
#  329              0.031  Document_330      1
#  348              0.030  Document_349      1
#  303              0.027  Document_304      1
#  335              0.026  Document_336      1
#  125              0.024  Document_126      1
#  357              0.021  Document_358      1
#  345              0.021  Document_346      1
#  347              0.018  Document_348      1
#  316              0.018  Document_317      1
#  314              0.017  Document_315      1
#  315              0.016  Document_316      1
#  124              0.013  Document_125      1
#  215              0.013  Document_216      1
#  344              0.012  Document_345      1
#  332              0.012  Document_333      1
#  181              0.012  Document_182      1
#  68               0.011   Document_69      1
#  238              0.011  Document_239      1
#  194              0.010  Document_195      1
#  180              0.010  Document_181      1
#  331              0.000  Document_332      0
#  ..                 ...           ...    ...
#  98               0.000   Document_99      0
#  97               0.000   Document_98      0
#  96               0.000   Document_97      0
#  95               0.000   Document_96      0
#  94               0.000   Document_95      0
#  93               0.000   Document_94      0
#  92               0.000   Document_93      0
#  110              0.000  Document_111      0
#  112              0.000  Document_113      0
#  135              0.000  Document_136      0
#  126              0.000  Document_127      0
#  134              0.000  Document_135      0
#  133              0.000  Document_134      0
#  132              0.000  Document_133      0
#  131              0.000  Document_132      0
#  130              0.000  Document_131      0
#  129              0.000  Document_130      0
#  128              0.000  Document_129      0
#  127              0.000  Document_128      0
#  123              0.000  Document_124      0
#  113              0.000  Document_114      0
#  121              0.000  Document_122      0
#  120              0.000  Document_121      0
#  119              0.000  Document_120      0
#  118              0.000  Document_119      0
#  117              0.000  Document_118      0
#  116              0.000  Document_117      0
#  115              0.000  Document_116      0
#  114              0.000  Document_115      0
#  359              0.000  Document_360      0
#
#                                                    Link
#  287  https://khotbahjumat.com/1624-bangsa-indonesia...
#  325  http://www.suaramuhammadiyah.id/2016/01/15/drs...
#  346  http://www.suaramuhammadiyah.id/2016/07/28/ana...
#  122  https://khotbahjumat.com/3069-bahaya-kelompok-...
#  336  http://www.suaramuhammadiyah.id/2016/03/31/dah...
#  310  https://www.nu.or.id/post/read/94840/khutbah-j...
#  246  https://khotbahjumat.com/2556-bila-dukun-berke...
#  343  http://www.suaramuhammadiyah.id/2016/06/29/khu...
#  193  https://khotbahjumat.com/2817-siapapun-preside...
#  329  http://www.suaramuhammadiyah.id/2016/02/11/set...
#  348  http://www.suaramuhammadiyah.id/2016/08/11/dua...
#  303  https://khotbahjumat.com/1119-unjuk-rasa-dalam...
#  335  http://www.suaramuhammadiyah.id/2016/03/17/mer...
#  125  https://khotbahjumat.com/3058-adab-adab-kepada...
#  357  http://www.suaramuhammadiyah.id/2017/01/26/neg...
#  345  http://www.suaramuhammadiyah.id/2016/07/01/pua...
#  347  http://www.suaramuhammadiyah.id/2016/08/04/ger...
#  316  https://www.nu.or.id/post/read/96676/khutbah-j...
#  314  https://www.nu.or.id/post/read/96060/khutbah-j...
#  315  https://www.nu.or.id/post/read/96642/khutbah-j...
#  124  https://khotbahjumat.com/3061-islam-dan-libera...
#  215  https://khotbahjumat.com/2694-khotbah-jumat-me...
#  344  http://www.suaramuhammadiyah.id/2016/07/01/aga...
#  332  http://www.suaramuhammadiyah.id/2016/02/26/ger...
#  181  https://khotbahjumat.com/2858-nikah-beda-agama...
#  68   https://khotbahjumat.com/3429-perumpamaan-seor...
#  238  https://khotbahjumat.com/2597-menjauhi-dosa-si...
#  194  https://khotbahjumat.com/2814-mewaspadai-pemik...
#  180  https://khotbahjumat.com/2861-boikot-produk-ya...
#  331  http://www.suaramuhammadiyah.id/2016/02/25/jan...
#  ..                                                 ...
#  98   https://khotbahjumat.com/3162-adakah-ghibah-ya...
#  97   https://khotbahjumat.com/3166-menggapai-ridha-...
#  96   https://khotbahjumat.com/3169-thagut-yang-bern...
#  95   https://khotbahjumat.com/3173-mengimani-kedata...
#  94   https://khotbahjumat.com/3176-tantangan-alqura...
#  93   https://khotbahjumat.com/3180-bicara-tanpa-pah...
#  92   https://khotbahjumat.com/3183-menjalin-hubunga...
#  110  https://khotbahjumat.com/3120-bersegera-menuju...
#  112  https://khotbahjumat.com/3106-kesialan-dan-keb...
#  135  https://khotbahjumat.com/3024-menjual-surga-de...
#  126  https://khotbahjumat.com/3055-tafsir-surat-at-...
#  134  https://khotbahjumat.com/3028-keutamaan-memper...
#  133  https://khotbahjumat.com/3031-umat-islam-menir...
#  132  https://khotbahjumat.com/3034-keutamaan-kalima...
#  131  https://khotbahjumat.com/3038-wahai-kepala-kel...
#  130  https://khotbahjumat.com/3041-islam-mengajarka...
#  129  https://khotbahjumat.com/3044-mengenal-arasy-m...
#  128  https://khotbahjumat.com/3049-mulia-dengan-men...
#  127  https://khotbahjumat.com/3052-menyikapi-karika...
#  123  https://khotbahjumat.com/3066-apakah-manusia-b...
#  113  https://khotbahjumat.com/3103-memahami-takdir-...
#  121  https://khotbahjumat.com/3072-asingnya-islam-d...
#  120  https://khotbahjumat.com/3075-dusta-pangkal-pe...
#  119  https://khotbahjumat.com/3083-meneladani-nabi-...
#  118  https://khotbahjumat.com/3086-buah-dari-keikhl...
#  117  https://khotbahjumat.com/3090-burung-hud-hud-p...
#  116  https://khotbahjumat.com/3093-menerapkan-syari...
#  115  https://khotbahjumat.com/3096-demonstrasi-pert...
#  114  https://khotbahjumat.com/3100-seribu-satu-seba...
#  359  http://www.suaramuhammadiyah.id/2017/02/16/mus...
#
#  [360 rows x 4 columns]]
